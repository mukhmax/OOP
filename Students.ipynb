# %%
students_list = []
lecturers_list = []

class Student:
#     students_list = []
    def __init__(self, name, surname, gender):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.finished_courses = []
        self.courses_in_progress = []
        self.grades = {}
        students_list.append(self)
        
    def rate_lecturer(self, lecturer, course, grade):
        if isinstance(lecturer, Lecturer) and course in self.courses_in_progress and course in lecturer.courses_attached and 0 < grade <= 10:
            if course in lecturer.grades:
                lecturer.grades[course] += [grade]
            else:
                lecturer.grades[course] = [grade]
        else:
            return 'Ошибка'
        
    def __str__(self):
        text = f'''Имя: {self.name}
Фамилия: {self.surname}
Средняя оценка за домашние задания: {self.medium_grade()}
Курсы в процессе изучения: {', '.join(self.courses_in_progress)}
Завершенные курсы: {', '.join(self.finished_courses)}
'''
        return text
        
    def medium_grade(self):
        total = 0
        for grade in self.grades.values():
            course_medium_grade = sum(grade) / len(grade)
            total += course_medium_grade
        return '{:.2f}'.format(total / len(self.grades))
    
    def __lt__(self, other):
        if not isinstance(other, Student):
            print('Сравнение не со студентом.')
            return
        return self.medium_grade() < other.medium_grade()
        
class Mentor:
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.courses_attached = []
    
class Lecturer(Mentor):
    def __init__(self, name, surname):
        super().__init__(name, surname)
        self.grades = {}
        lecturers_list.append(self)
        
    def rate_hw(self, student, course, grade):
        print('Лектор не может выставлять оценки.\n')
    
    def __str__(self):
        text = f'''Имя: {self.name}
Фамилия: {self.surname}
Средняя оценка за лекции: {self.medium_grade()}
        '''
        return text
        
    def medium_grade(self):
        total = 0
        for grade in self.grades.values():
            course_medium_grade = sum(grade) / len(grade)
            total += course_medium_grade
        return '{:.2f}'.format(total / len(self.grades))
    
    def __lt__(self, other):
        if not isinstance(other, Lecturer):
            print('Сравнение не с лектором.')
            return
        return self.medium_grade() < other.medium_grade()

class Reviewer(Mentor):
    def rate_hw(self, student, course, grade):
        if isinstance(student, Student) and course in self.courses_attached and course in student.courses_in_progress:
            if course in student.grades:
                student.grades[course] += [grade]
            else:
                student.grades[course] = [grade]
        else:
            return 'Ошибка'
    
    def __str__(self):
        text = f'''Имя: {self.name}
Фамилия: {self.surname}
        '''
        return text
    
def course_medium_students(stud_list, course):
    total = []
    counter = 0
    for student in stud_list:
        if course in student.courses_in_progress:
            total += student.grades[course]
            counter += 1
    if counter == 0:
        return 'Этот курс никто не изучает.'
    else:
        medium_students = '{:.2f}'.format(sum(total) / len(total))
        return f'Средний балл всех студентов на курсе "{course}": {medium_students}\n'
    
def course_medium_lecturers(lect_list, course):
    total = []
    counter = 0
    for lecturer in lect_list:
        if course in lecturer.courses_attached:
            total += lecturer.grades[course]
            counter += 1
    if counter == 0:
        return 'Этот курс никто не читает.'
    else:
        medium_lecturers = '{:.2f}'.format(sum(total) / len(total))
        return f'Средний балл всех лекторов на курсе "{course}": {medium_lecturers}\n'

best_student = Student('Ruoy', 'Eman', 'your_gender')
best_student.courses_in_progress += ['Python']
best_student.courses_in_progress += ['Основы программирования']
best_student.courses_in_progress += ['Высшая математика']
best_student.courses_in_progress += ['Алгоритмы']

medium_student = Student('Maksim', 'Mukhin', 'male')
medium_student.courses_in_progress += ['Python']
medium_student.courses_in_progress += ['Основы программирования']
medium_student.courses_in_progress += ['Высшая математика']
medium_student.courses_in_progress += ['Алгоритмы']
 
cool_mentor = Reviewer('Some', 'Buddy')
cool_mentor.courses_attached += ['Python']
cool_mentor.courses_attached += ['Основы программирования']

cool_reviewer = Reviewer('John', 'Smith')
cool_reviewer.courses_attached += ['Python']
cool_reviewer.courses_attached += ['Основы программирования']

math_lecturer = Lecturer('Vladimir', 'Semenov')
math_lecturer.courses_attached += ['Высшая математика']
math_lecturer.courses_attached += ['Алгоритмы']
math_lecturer.courses_attached += ['Основы программирования']

prog_lecturer = Lecturer('Stephen', 'Wozniak')
prog_lecturer.courses_attached += ['Python']
prog_lecturer.courses_attached += ['Основы программирования']
prog_lecturer.courses_attached += ['Алгоритмы']

best_student.rate_lecturer(math_lecturer, 'Высшая математика', 9)
best_student.rate_lecturer(math_lecturer, 'Высшая математика', 9)
best_student.rate_lecturer(math_lecturer, 'Высшая математика', 10)

medium_student.rate_lecturer(math_lecturer, 'Алгоритмы', 8)
medium_student.rate_lecturer(math_lecturer, 'Алгоритмы', 9)
medium_student.rate_lecturer(math_lecturer, 'Алгоритмы', 7)

best_student.rate_lecturer(prog_lecturer, 'Python', 8)
best_student.rate_lecturer(prog_lecturer, 'Python', 9)
best_student.rate_lecturer(prog_lecturer, 'Python', 8)

medium_student.rate_lecturer(prog_lecturer, 'Основы программирования', 8)
medium_student.rate_lecturer(prog_lecturer, 'Основы программирования', 10)
medium_student.rate_lecturer(prog_lecturer, 'Основы программирования', 7)

cool_mentor.rate_hw(best_student, 'Python', 10)
cool_mentor.rate_hw(best_student, 'Python', 9)
cool_mentor.rate_hw(best_student, 'Python', 8)
cool_mentor.rate_hw(best_student, 'Основы программирования', 9)
cool_mentor.rate_hw(best_student, 'Основы программирования', 8)
cool_mentor.rate_hw(best_student, 'Основы программирования', 8)

cool_reviewer.rate_hw(medium_student, 'Python', 9)
cool_reviewer.rate_hw(medium_student, 'Python', 8)
cool_reviewer.rate_hw(medium_student, 'Python', 7)
cool_reviewer.rate_hw(medium_student, 'Основы программирования', 9)
cool_reviewer.rate_hw(medium_student, 'Основы программирования', 9)
cool_reviewer.rate_hw(medium_student, 'Основы программирования', 7)

prog_lecturer.rate_hw(medium_student, 'Основы программирования', 9)
print(cool_mentor)
print(math_lecturer)
print(prog_lecturer)
print(best_student)
print(medium_student)
print('Сравнение студентов:')
print(best_student > medium_student)
print()
print('Сравнение лекторов:')
print(math_lecturer > prog_lecturer)
print()
print(course_medium_students(students_list, 'Основы программирования'))
print(course_medium_lecturers(lecturers_list, 'Высшая математика'))
# Out:
# Лектор не может выставлять оценки.
#
# Имя: Some
# Фамилия: Buddy
#
# Имя: Vladimir
# Фамилия: Semenov
# Средняя оценка за лекции: 8.67
#
# Имя: Stephen
# Фамилия: Wozniak
# Средняя оценка за лекции: 8.33
#
# Имя: Ruoy
# Фамилия: Eman
# Средняя оценка за домашние задания: 8.67
# Курсы в процессе изучения: Python, Основы программирования, Высшая математика, Алгоритмы
# Завершенные курсы:
#
# Имя: Maksim
# Фамилия: Mukhin
# Средняя оценка за домашние задания: 8.17
# Курсы в процессе изучения: Python, Основы программирования, Высшая математика, Алгоритмы
# Завершенные курсы:
#
# Сравнение студентов:
# True
#
# Сравнение лекторов:
# True
#
# Средний балл всех студентов на курсе "Основы программирования": 8.33
#
# Средний балл всех лекторов на курсе "Высшая математика": 9.33
